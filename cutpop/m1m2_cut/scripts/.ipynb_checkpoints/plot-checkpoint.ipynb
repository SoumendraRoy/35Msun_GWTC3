# %%
import numpy as np
import matplotlib.pylab as plt
import xarray as xr
import corner

# %%
ds = xr.open_dataset("../data/chain_0.5.nc")
var = next(iter(ds.data_vars))
arr = ds[var].values

# %%
labels = [r'$\alpha$',r'$\mu$',r'$\sigma$',r'$\beta$',r'$\lambda$',r'$\mu_{\chi_{eff}}$',r'$\sigma_{\chi_{eff}}$']

true = np.array([3.0, 33.0, 3.0, 1.5, 3.0, 0.2, 10.**(-0.95)])
figure = corner.corner(
    arr.T,
    labels=labels,
    quantiles=[0.05, 0.5, 0.95],
    show_titles=True,
    title_kwargs={"fontsize": 18},
    label_kwargs={"fontsize": 18},
    color="black",      # Recovered (black)
)

# Extract the axes
axes = np.array(figure.axes).reshape((len(true), len(true)))

# Loop over the diagonal (1D histograms)
for i in range(len(true)):
    ax = axes[i, i]
    ax.axvline(true[i], color="r", label="Injected" if i == 0 else None)

# Loop over the 2D panels
for yi in range(len(true)):
    for xi in range(yi):
        ax = axes[yi, xi]
        ax.axvline(true[xi], color="r")
        ax.axhline(true[yi], color="r")
        ax.plot(true[xi], true[yi], "sr")

# Create legend handles with thicker lines
handles = [
    plt.Line2D([], [], color="r", lw=3, label="Injected"),
    plt.Line2D([], [], color="black", lw=3, label="Recovered"),
]

# Add large legend slightly inward
figure.legend(
    handles=handles,
    loc="upper right",
    bbox_to_anchor=(0.7, 0.75),   # adjust (x, y) if you want different placement
    fontsize=18,                  # larger legend text
    frameon=False,
    handlelength=2.5,             # make line handles longer
    handletextpad=0.8,            # spacing between line and text
)

figure.savefig("../figures/appen_D_corner_plot.pdf", bbox_inches="tight")
plt.show()
